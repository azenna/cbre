# %%
import pandas as pd
import numpy as np
import torch

# %%
property_insights = pd.read_csv("../data/property_insights_extended.csv")
recommendation_engine_users = pd.read_csv("../data/recommendation_engine_users.csv")
roles_insights = pd.read_csv("../data/roles_duties_and_insights.csv")

# %%
print(property_insights["Insight 1"].unique())
print(property_insights["Insight 2"].unique())
property_insights.head()
# Out:
# ['Budgets' 'Energy Usage' 'Work Orders' 'Leases' 'Compliance'
#  'Accessibility' 'Safety Incidents' 'Tenant Satisfaction']
# ['Janitorial Expenses 10% Over Mean' 'Off-Hours' 'Energy Efficiency'
#  'Budget Compliance' 'Preventative' 'Renewal Rate' 'Peak Hours'
#  'Non-Compliance Incidents' 'Occupancy' 'Compliance Score'
#  'Regulatory Updates' 'Completion Rate' 'Reactive' 'Expiring'
#  'Energy Cost Variance' 'Elevator Status' 'ADA Compliance'
#  'Hazardous Materials' 'Lease Satisfaction' 'Noise Complaints'
#  'Fire Safety' 'Electrical Issues' 'Amenities Feedback'
#  'Public Transport Access']
#                      Property Address     Insight 1  \
# 0          2483 Olson Via St, Houston       Budgets
# 1       8389 Chad Village St, Houston  Energy Usage
# 2         3427 James Shoal St, Boston  Energy Usage
# 3    9659 Angela Estates St, New York  Energy Usage
# 4  6752 Cameron Extension St, Atlanta       Budgets
#
# ...

# %%
recommendation_engine_users.head()
# Out:
#             Name                  Email                  Role  \
# 0  Charles Potts      amy99@hotmail.com  Facility Coordinator
# 1  Charles Potts      amy99@hotmail.com  Facility Coordinator
# 2  Charles Potts      amy99@hotmail.com  Facility Coordinator
# 3   Shannon Rose  colemantina@gmail.com      Building Manager
# 4   Shannon Rose  colemantina@gmail.com      Building Manager
#
#           Business Line Location           Client              Dashboard  \
# 0     Energy Management   Boston  TechSphere Inc.  Maintenance Schedules
# 1     Energy Management   Boston  TechSphere Inc.   Facility Utilization
# 2     Energy Management   Boston  TechSphere Inc.  Maintenance Schedules
# 3  Lease Administration  Atlanta   EverGrow Farms         Occupancy Rate
# 4  Lease Administration  Atlanta   EverGrow Farms        Building Health
#
#    User Activity
# 0             27
# 1             38
# 2             69
# 3             11
# 4             32

# %%
roles_insights
# Out:
#                      Role                                             Duties  \
# 0              Technician  Responsible for equipment maintenance and repa...
# 1        Building Manager                Manages a single building or asset.
# 2        Account Director  Oversees client accounts and relationships acr...
# 3          Chief Engineer  Responsible for all engineering and technical ...
# 4       Portfolio Manager  Oversees the performance of a collection of as...
# 5           Asset Manager         Has scope of all buildings in a portfolio.
# 6         Leasing Manager      Manages leases for one or multiple buildings.
# 7    Facility Coordinator     Coordinates facility activities and schedules.
# 8  Maintenance Supervisor  Oversees maintenance activities for one or mor...
#
#                                  Relevant Insights
# 0          Equipment Health, Work Order Completion
# 1                  Building Health, Occupancy Rate
# ...

# %%
relevanceMap = {"Equitment Health":,
                "Work Order Completion: "Work Orders",}
